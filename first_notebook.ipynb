# %%
print("Hello World")
# Out:
# Hello World

# %%
text = "learning python"
number = 14
pi = 3.14

# %%
type(text)
# Out:
# str

# %%
type(number)
# Out:
# int

# %%
type(pi)
# Out:
# float

# %%
def add(a, b): # add to number
  total = a + b
  return total

# %%
add(5, 10)
# Out:
# 15

# %%
sum = add(5, 10)

# %%
print(sum)
# Out:
# 15
